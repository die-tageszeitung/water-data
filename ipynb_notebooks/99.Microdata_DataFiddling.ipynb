# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
selectedmicrodata = pd.read_csv('/Users/francescamorini/projects/water-data/results/microdata/microdata_selectedrecipients.csv', sep=';')

# %%
selectedmicrodata.sample(5)
# Out:
#      Unnamed: 0 DonorName RecipientName  DonorCode  RecipientCode  \
# 146      327386   Germany         India          5            645
# 274      494845   Germany         India          5            645
# 326      552883   Germany         Kenya          5            248
# 694     1578802   Germany         India          5            645
# 610     1409485   Germany         Kenya          5            248
#
#     IncomegroupName  USD_Commitment_Defl  USD_Received_Defl  \
# 146           LMICs             0.538332                NaN
# 274           LMICs             0.066601                NaN
# 326           LMICs             5.635890                NaN
# 694           LMICs             0.055073                0.0
# 610           LMICs             0.151343                0.0
#
#                                       ShortDescription  \
# 146               BMZ TC:WATER SUPPLY/SANIT.-SMALL SYS
# 274                   GOVERNMENT CONTRIBUTIONS VIA NGO
# 326                                WATER SECTOR REFORM
# 694  SCIENTIFIC COOPERATION WITH OTHER COUNTRIES (N...
# 610  BIWAC - STRENGHTENING OF REGIONAL WATER SUPPLI...
#
#                                             AgencyName  ...  \
# 146  Bundesministerium für Wirtschaftliche Zusammen...  ...
# 274          Foundations/Societies/Misc. (non federal)  ...
# 326  Deutsche Gesellschaft für Internationale Zusam...  ...
# 694         Federal Ministry of Education and Research  ...
# 610                           Federal State of Bavaria  ...
#
#                                            ChannelName  \
# 146                                                NaN
# 274                                                NaN
# 326                                                NaN
# 694  University, college or other teaching institut...
# 610  University, college or other teaching institut...
#
#                                    ChannelReportedName ExpectedStartDate  \
# 146                                                NaN               NaN
# 274                                                NaN               NaN
# 326                                                NaN               NaN
# 694  Teaching institution/Research and development ...        2016-07-01
# 610  Teaching institution/Research and development ...        2017-04-10
#
#     CompletionDate                                    LongDescription  \
# 146            NaN                                                NaN
# 274            NaN                                                NaN
# 326            NaN                                                NaN
# 694     2019-06-30  DNA Biochip (Deoxyribonucleic Acid) for on-sit...
# 610     2018-12-31  BIWAC - Strenghtening of regional water suppli...
#
#     CommitmentDate Recipientstat SI.SPR.PCAP Recipientstat SI.POV.XPND.MD  \
# 146     1997-12-31                       0.0                          0.0
# 274     2002-12-31                       0.0                          0.0
# 326     2004-12-31                       0.0                          0.0
# 694     2018-01-01                       0.0                          0.0
# 610     2017-12-31                       0.0                          0.0
#
#     Recipientstat SP.POP.TOTL Recipientstat AG.SRF.TOTL.K2
# 146              1.000900e+09                 3.287260e+06
# 274              1.093317e+09                 3.287260e+06
# 326              3.563527e+07                 5.803700e+05
# 694              1.352617e+09                 3.287259e+06
# 610              5.022147e+07                 5.803700e+05
#
# [5 rows x 25 columns]

# %% [markdown]
# Creating a slim version of data to avoid too many fields for vis and trailing commas problem

# %%
cleaned_selection = selectedmicrodata.drop(columns=["Unnamed: 0","ProjectTitle","PurposeName","SectorName","ExpectedStartDate","CompletionDate","LongDescription"])

# %%
cleaned_selection.sample(5)
# Out:
#      DonorName RecipientName IncomegroupName  USD_Commitment_Defl  \
# 1042   Germany      Ethiopia            LDCs             3.632030
# 93     Germany       Burundi            LDCs             7.055230
# 947    Germany       Burundi            LDCs            21.580900
# 891    Germany        Uganda            LDCs             0.011421
# 600    Germany         Sudan            LDCs             0.007898
#
#       USD_Received_Defl                                   ShortDescription  \
# 1042               -0.0              REGIONAL UNHCR PROJECT IN EAST AFRICA
# 93                  NaN                                 RURAL WATER SUPPLY
# 947                -0.0  WATER AND SANITATION SECTORAL PROGRAMME, PHASE...
# 891                -0.0  WATER RESOURCES POLICY AND ADMINISTRATIVE MANA...
# 600                -0.0  THE EXPERT IS ASSIGNED FOR TRAINING AND LECTUR...
#
#                                             ChannelName  \
# 1042  United Nations Office of the United Nations Hi...
# 93                                                  NaN
# 947                          Public Sector Institutions
# 891                          Public Sector Institutions
# 600                          Public Sector Institutions
#
#                                     ChannelReportedName CommitmentDate
# 1042  United Nations Office of the United Nations Hi...     2016-05-10
# 93                               MINISTERE DES FINANCES     1994-09-01
# 947                                                 KfW     2013-01-22
# 891                                                 GIZ            NaN
# 600                                       Public sector            NaN

# %% [markdown]
# Exporting with standard sep and no index for prototyping

# %%
cleaned_selection.to_csv('new_microdata.csv', sep=',', index=False)

# %% [markdown]
# Doing some calculations to get money % according to income groups

# %%
countries = cleaned_selection['RecipientName'].unique()

# %%
countries
# Out:
# array(['Tanzania', 'Bolivia', 'Kenya', 'Ethiopia', 'Sudan', 'Burundi',
#        'Bangladesh', 'Lebanon', 'Egypt', 'Rwanda', 'India', 'Colombia',
#        'Uganda'], dtype=object)

# %%
#Calculating projects % values for income groups and single countries

incomeNames = ['LMICs', 'LDCs', 'UMICs']
fullTotal = 0

for name in incomeNames: 
    total = cleaned_selection["USD_Commitment_Defl"].sum()
    sumElement = cleaned_selection["USD_Commitment_Defl"].loc[cleaned_selection["IncomegroupName"] == name].sum()
    subSelection = cleaned_selection.loc[cleaned_selection["IncomegroupName"] == name]
    perc = sumElement * 100 / total
    fullTotal = fullTotal + perc
    subTotal = 0
    print(name)
    print(perc)
    print('--------')
    
    for country in countries:
        sumCountry = subSelection["USD_Commitment_Defl"].loc[subSelection["RecipientName"] == country].sum() 
        subPerc = sumCountry * 100 / total
        subTotal = subTotal + subPerc
        if subPerc != 0:
            print(country)
            print(subPerc)
    print(subTotal)
    print('--------')
    
print(fullTotal)
# Out:
# LMICs
# 58.2412134936116
# --------
# Bolivia
# 11.95913699745467
# Kenya
# 14.151360672533468
# Egypt
# 17.260749453275313
# India
# 14.86996637034815
# 58.2412134936116
# --------
# LDCs
# 34.88454453864079
# --------
# Tanzania
# 13.085009347279655
# Ethiopia
# 2.121438322643363
# Sudan
# 2.1670801576507426
# Burundi
# 6.167040549987557
# Bangladesh
# 2.5428288881536587
# Rwanda
# 1.3280894132733618
# Uganda
# 7.47305785965245
# 34.88454453864079
# --------
# UMICs
# 6.874241967747618
# --------
# Lebanon
# 4.828232301297417
# Colombia
# 2.0460096664501997
# 6.874241967747617
# --------
# 100.00000000000001

# %% [markdown]
# Working on time series to determine how spending evolved.

# %%
cleaned_selection["CommitmentDate"] = pd.to_datetime(cleaned_selection["CommitmentDate"])

# %%
cleaned_selection['year'] = cleaned_selection["CommitmentDate"].dt.year

# %%
cleaned_selection.sample(5)
# Out:
#      DonorName RecipientName IncomegroupName  USD_Commitment_Defl  \
# 364    Germany       Lebanon           UMICs             0.008995
# 256    Germany       Lebanon           UMICs             0.147231
# 339    Germany      Tanzania            LDCs             8.559590
# 885    Germany        Uganda            LDCs             0.003769
# 1178   Germany         Kenya           LMICs            17.370500
#
#       USD_Received_Defl                              ShortDescription  \
# 364                 NaN                     WASTE MANAGEMENT/DISPOSAL
# 256                 NaN                  DRINKING WATER STERILISATION
# 339                 NaN      RURAL WATER SUPPLY EAST KILIMAJA, PH. II
# 885                -0.0    WATER SUPPLY AND SANITATION -LARGE SYSTEMS
# 1178                0.0  WATER AND SANITATION TO PROTECT BIODIVERSITY
#
#                      ChannelName ChannelReportedName CommitmentDate    year
# 364   Public Sector Institutions       Public sector     2005-12-31  2005.0
# 256                          NaN                 NaN     2002-12-31  2002.0
# 339   Public Sector Institutions       Public sector     2005-07-12  2005.0
# 885   Public Sector Institutions                 GIZ            NaT     NaN
# 1178          Central Government  Central Government     2019-12-30  2019.0

# %% [markdown]
# The data goes way back before 1980!

# %%
cleaned_selection["CommitmentDate"].min()
# Out:
# Timestamp('1973-05-01 00:00:00')

# %%
cleaned_selection["CommitmentDate"].max()
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
sorted_selection = cleaned_selection.sort_values(by='CommitmentDate', ascending=True, inplace=False, kind='quicksort', na_position='last')

# %%
cleaned_selection.to_csv('data/historically_ordered.csv', sep=',', index=False,na_rep='NaN')

# %% [markdown]
# Checking what's NaN. A lot of information on projects years and Donor's channel.

# %%
cleaned_selection.isna().sum()
# Out:
# DonorName                0
# RecipientName            0
# IncomegroupName          0
# USD_Commitment_Defl      0
# USD_Received_Defl      301
# ShortDescription         0
# ChannelName            308
# ChannelReportedName    233
# CommitmentDate         445
# year                   445
# dtype: int64

# %% [markdown]
# Generating a file with only labels and counts to see if there are recurring projects or similar projects appearing.

# %%
labels = cleaned_selection['ShortDescription'].unique()
value_counts = cleaned_selection['ShortDescription'].value_counts()


project_descriptions = pd.DataFrame(value_counts)

# %%
project_descriptions
# Out:
#      level_0                                              index  \
# 0          0   BASIC DRINKING WATER SUPPLY AND BASIC SANITATION
# 1          1        WATER SUPPLY AND SANITATION - LARGE SYSTEMS
# 2          2                         WATER RESOURCES PROTECTION
# 3          3  SCIENTIFIC COOPERATION WITH OTHER COUNTRIES (N...
# 4          4                 WATER RESOURCES POLICY/ADMIN. MGMT
# ..       ...                                                ...
# 539      539                           WATER TANKS FOR TANZANIA
# 540      540             WATER FOR THE NOMADS IN NORTHERN KENYA
# 541      541               NAIROBI WATER DISTRIBUTION PROGRAMME
# 542      542                               WATER SUPPLY, TABORA
# 543      543  IMPROVEMENT OF WATER, HYGIENE AND SANITATION C...
#
#      ShortDescription                                              label
# 0                  94   BASIC DRINKING WATER SUPPLY AND BASIC SANITATION
# 1                  35        WATER SUPPLY AND SANITATION - LARGE SYSTEMS
# 2                  35                         WATER RESOURCES PROTECTION
# 3                  32  SCIENTIFIC COOPERATION WITH OTHER COUNTRIES (N...
# 4                  27                 WATER RESOURCES POLICY/ADMIN. MGMT
# ..                ...                                                ...
# 539                 1                           WATER TANKS FOR TANZANIA
# 540                 1             WATER FOR THE NOMADS IN NORTHERN KENYA
# 541                 1               NAIROBI WATER DISTRIBUTION PROGRAMME
# 542                 1                               WATER SUPPLY, TABORA
# 543                 1  IMPROVEMENT OF WATER, HYGIENE AND SANITATION C...
#
# [544 rows x 4 columns]

# %%
project_descriptions.reset_index(level=0, inplace=True)

# %%
clean_descriptions = project_descriptions.drop(columns=['index', 'level_0'])

# %%
clean_descriptions.to_csv('data/projects_descriptions.csv', sep=',', index=False,na_rep='NaN')

# %%
years = sorted_selection['year'].unique()
years
# Out:
# array([1973., 1974., 1975., 1976., 1977., 1978., 1979., 1980., 1981.,
#        1982., 1983., 1984., 1985., 1986., 1987., 1988., 1989., 1990.,
#        1991., 1992., 1993., 1994., 1995., 1996., 1997., 1998., 1999.,
#        2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007., 2008.,
#        2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016., 2017.,
#        2018., 2019.,   nan])

# %%
sumValues = []

for year in years:
    singleyear = sorted_selection.loc[sorted_selection['year'] == year, 'USD_Commitment_Defl'].sum()
    sumValues.append(singleyear)

import statistics
statistics.mean(sumValues)
# Out:
# DonorName              1
# RecipientName          1
# IncomegroupName        1
# USD_Commitment_Defl    1
# USD_Received_Defl      0
# ShortDescription       1
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         1
# year                   1
# dtype: int64
# DonorName              4
# RecipientName          4
# IncomegroupName        4
# USD_Commitment_Defl    4
# USD_Received_Defl      4
# ShortDescription       4
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         4
# year                   4
# dtype: int64
# DonorName              3
# RecipientName          3
# IncomegroupName        3
# USD_Commitment_Defl    3
# USD_Received_Defl      2
# ShortDescription       3
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         3
# year                   3
# dtype: int64
# DonorName              3
# RecipientName          3
# IncomegroupName        3
# USD_Commitment_Defl    3
# USD_Received_Defl      1
# ShortDescription       3
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         3
# year                   3
# dtype: int64
# DonorName              8
# RecipientName          8
# IncomegroupName        8
# USD_Commitment_Defl    8
# USD_Received_Defl      4
# ShortDescription       8
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         8
# year                   8
# dtype: int64
# DonorName              4
# RecipientName          4
# IncomegroupName        4
# USD_Commitment_Defl    4
# USD_Received_Defl      2
# ShortDescription       4
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         4
# year                   4
# dtype: int64
# DonorName              1
# RecipientName          1
# IncomegroupName        1
# USD_Commitment_Defl    1
# USD_Received_Defl      0
# ShortDescription       1
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         1
# year                   1
# dtype: int64
# DonorName              2
# RecipientName          2
# IncomegroupName        2
# USD_Commitment_Defl    2
# USD_Received_Defl      1
# ShortDescription       2
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         2
# year                   2
# dtype: int64
# DonorName              4
# RecipientName          4
# IncomegroupName        4
# USD_Commitment_Defl    4
# USD_Received_Defl      2
# ShortDescription       4
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         4
# year                   4
# dtype: int64
# DonorName              5
# RecipientName          5
# IncomegroupName        5
# USD_Commitment_Defl    5
# USD_Received_Defl      4
# ShortDescription       5
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         5
# year                   5
# dtype: int64
# DonorName              5
# RecipientName          5
# IncomegroupName        5
# USD_Commitment_Defl    5
# USD_Received_Defl      2
# ShortDescription       5
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         5
# year                   5
# dtype: int64
# DonorName              3
# RecipientName          3
# IncomegroupName        3
# USD_Commitment_Defl    3
# USD_Received_Defl      1
# ShortDescription       3
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         3
# year                   3
# dtype: int64
# DonorName              8
# RecipientName          8
# IncomegroupName        8
# USD_Commitment_Defl    8
# USD_Received_Defl      1
# ShortDescription       8
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         8
# year                   8
# dtype: int64
# DonorName              5
# RecipientName          5
# IncomegroupName        5
# USD_Commitment_Defl    5
# USD_Received_Defl      2
# ShortDescription       5
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         5
# year                   5
# dtype: int64
# DonorName              2
# RecipientName          2
# IncomegroupName        2
# USD_Commitment_Defl    2
# USD_Received_Defl      1
# ShortDescription       2
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         2
# year                   2
# dtype: int64
# DonorName              6
# RecipientName          6
# IncomegroupName        6
# USD_Commitment_Defl    6
# USD_Received_Defl      1
# ShortDescription       6
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         6
# year                   6
# dtype: int64
# DonorName              2
# RecipientName          2
# IncomegroupName        2
# USD_Commitment_Defl    2
# USD_Received_Defl      2
# ShortDescription       2
# ChannelName            0
# ChannelReportedName    1
# CommitmentDate         2
# year                   2
# dtype: int64
# DonorName              6
# RecipientName          6
# IncomegroupName        6
# USD_Commitment_Defl    6
# USD_Received_Defl      1
# ShortDescription       6
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         6
# year                   6
# dtype: int64
# DonorName              6
# RecipientName          6
# IncomegroupName        6
# USD_Commitment_Defl    6
# USD_Received_Defl      0
# ShortDescription       6
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         6
# year                   6
# dtype: int64
# DonorName              7
# RecipientName          7
# IncomegroupName        7
# USD_Commitment_Defl    7
# USD_Received_Defl      2
# ShortDescription       7
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         7
# year                   7
# dtype: int64
# DonorName              2
# RecipientName          2
# IncomegroupName        2
# USD_Commitment_Defl    2
# USD_Received_Defl      0
# ShortDescription       2
# ChannelName            0
# ChannelReportedName    1
# CommitmentDate         2
# year                   2
# dtype: int64
# DonorName              11
# RecipientName          11
# IncomegroupName        11
# USD_Commitment_Defl    11
# USD_Received_Defl       5
# ShortDescription       11
# ChannelName             0
# ChannelReportedName    11
# CommitmentDate         11
# year                   11
# dtype: int64
# DonorName              6
# RecipientName          6
# IncomegroupName        6
# USD_Commitment_Defl    6
# USD_Received_Defl      2
# ShortDescription       6
# ChannelName            0
# ChannelReportedName    6
# CommitmentDate         6
# year                   6
# dtype: int64
# DonorName              6
# RecipientName          6
# IncomegroupName        6
# USD_Commitment_Defl    6
# USD_Received_Defl      3
# ShortDescription       6
# ChannelName            0
# ChannelReportedName    6
# CommitmentDate         6
# year                   6
# dtype: int64
# DonorName              11
# RecipientName          11
# IncomegroupName        11
# USD_Commitment_Defl    11
# USD_Received_Defl       2
# ShortDescription       11
# ChannelName             0
# ChannelReportedName     4
# CommitmentDate         11
# year                   11
# dtype: int64
# DonorName              9
# RecipientName          9
# IncomegroupName        9
# USD_Commitment_Defl    9
# USD_Received_Defl      1
# ShortDescription       9
# ChannelName            0
# ChannelReportedName    3
# CommitmentDate         9
# year                   9
# dtype: int64
# DonorName              22
# RecipientName          22
# IncomegroupName        22
# USD_Commitment_Defl    22
# USD_Received_Defl       1
# ShortDescription       22
# ChannelName             0
# ChannelReportedName     5
# CommitmentDate         22
# year                   22
# dtype: int64
# DonorName              23
# RecipientName          23
# IncomegroupName        23
# USD_Commitment_Defl    23
# USD_Received_Defl       1
# ShortDescription       23
# ChannelName             0
# ChannelReportedName     6
# CommitmentDate         23
# year                   23
# dtype: int64
# DonorName              34
# RecipientName          34
# IncomegroupName        34
# USD_Commitment_Defl    34
# USD_Received_Defl       3
# ShortDescription       34
# ChannelName             0
# ChannelReportedName     9
# CommitmentDate         34
# year                   34
# dtype: int64
# DonorName              33
# RecipientName          33
# IncomegroupName        33
# USD_Commitment_Defl    33
# USD_Received_Defl       0
# ShortDescription       33
# ChannelName             0
# ChannelReportedName    10
# CommitmentDate         33
# year                   33
# dtype: int64
# DonorName              22
# RecipientName          22
# IncomegroupName        22
# USD_Commitment_Defl    22
# USD_Received_Defl       0
# ShortDescription       22
# ChannelName             0
# ChannelReportedName     6
# CommitmentDate         22
# year                   22
# dtype: int64
# DonorName              44
# RecipientName          44
# IncomegroupName        44
# USD_Commitment_Defl    44
# USD_Received_Defl       2
# ShortDescription       44
# ChannelName             0
# ChannelReportedName     7
# CommitmentDate         44
# year                   44
# dtype: int64
# DonorName              72
# RecipientName          72
# IncomegroupName        72
# USD_Commitment_Defl    72
# USD_Received_Defl      26
# ShortDescription       72
# ChannelName            72
# ChannelReportedName    72
# CommitmentDate         72
# year                   72
# dtype: int64
# DonorName              55
# RecipientName          55
# IncomegroupName        55
# USD_Commitment_Defl    55
# USD_Received_Defl      55
# ShortDescription       55
# ChannelName            55
# ChannelReportedName    55
# CommitmentDate         55
# year                   55
# dtype: int64
# DonorName              11
# RecipientName          11
# IncomegroupName        11
# USD_Commitment_Defl    11
# USD_Received_Defl      11
# ShortDescription       11
# ChannelName            11
# ChannelReportedName    11
# CommitmentDate         11
# year                   11
# dtype: int64
# DonorName              3
# RecipientName          3
# IncomegroupName        3
# USD_Commitment_Defl    3
# USD_Received_Defl      3
# ShortDescription       3
# ChannelName            3
# ChannelReportedName    3
# CommitmentDate         3
# year                   3
# dtype: int64
# DonorName              8
# RecipientName          8
# IncomegroupName        8
# USD_Commitment_Defl    8
# USD_Received_Defl      8
# ShortDescription       8
# ChannelName            8
# ChannelReportedName    8
# CommitmentDate         8
# year                   8
# dtype: int64
# DonorName              7
# RecipientName          7
# IncomegroupName        7
# USD_Commitment_Defl    7
# USD_Received_Defl      7
# ShortDescription       7
# ChannelName            7
# ChannelReportedName    7
# CommitmentDate         7
# year                   7
# dtype: int64
# DonorName              12
# RecipientName          12
# IncomegroupName        12
# USD_Commitment_Defl    12
# USD_Received_Defl      12
# ShortDescription       12
# ChannelName            12
# ChannelReportedName    12
# CommitmentDate         12
# year                   12
# dtype: int64
# DonorName              24
# RecipientName          24
# IncomegroupName        24
# USD_Commitment_Defl    24
# USD_Received_Defl      24
# ShortDescription       24
# ChannelName            24
# ChannelReportedName    24
# CommitmentDate         24
# year                   24
# dtype: int64
# DonorName              37
# RecipientName          37
# IncomegroupName        37
# USD_Commitment_Defl    37
# USD_Received_Defl      37
# ShortDescription       37
# ChannelName            37
# ChannelReportedName    37
# CommitmentDate         37
# year                   37
# dtype: int64
# DonorName              27
# RecipientName          27
# IncomegroupName        27
# USD_Commitment_Defl    27
# USD_Received_Defl      27
# ShortDescription       27
# ChannelName            27
# ChannelReportedName    27
# CommitmentDate         27
# year                   27
# dtype: int64
# DonorName              33
# RecipientName          33
# IncomegroupName        33
# USD_Commitment_Defl    33
# USD_Received_Defl      33
# ShortDescription       33
# ChannelName            33
# ChannelReportedName    33
# CommitmentDate         33
# year                   33
# dtype: int64
# DonorName              26
# RecipientName          26
# IncomegroupName        26
# USD_Commitment_Defl    26
# USD_Received_Defl      26
# ShortDescription       26
# ChannelName            26
# ChannelReportedName    26
# CommitmentDate         26
# year                   26
# dtype: int64
# DonorName              46
# RecipientName          46
# IncomegroupName        46
# USD_Commitment_Defl    46
# USD_Received_Defl      46
# ShortDescription       46
# ChannelName            46
# ChannelReportedName    46
# CommitmentDate         46
# year                   46
# dtype: int64
# DonorName              51
# RecipientName          51
# IncomegroupName        51
# USD_Commitment_Defl    51
# USD_Received_Defl      51
# ShortDescription       51
# ChannelName            51
# ChannelReportedName    51
# CommitmentDate         51
# year                   51
# dtype: int64
# DonorName              43
# RecipientName          43
# IncomegroupName        43
# USD_Commitment_Defl    43
# USD_Received_Defl      43
# ShortDescription       43
# ChannelName            43
# ChannelReportedName    43
# CommitmentDate         43
# year                   43
# dtype: int64
# DonorName              0
# RecipientName          0
# IncomegroupName        0
# USD_Commitment_Defl    0
# USD_Received_Defl      0
# ShortDescription       0
# ChannelName            0
# ChannelReportedName    0
# CommitmentDate         0
# year                   0
# dtype: int64
# 89.10677331041667

# %%
regions = sorted_selection['RecipientName'].unique()
regions
# Out:
# array(['Tanzania', 'Bolivia', 'Kenya', 'Ethiopia', 'Sudan', 'Burundi',
#        'Bangladesh', 'Egypt', 'Lebanon', 'Rwanda', 'India', 'Colombia',
#        'Uganda'], dtype=object)

# %%
for region in regions:
    print(region)
    
    allentries = sorted_selection.loc[sorted_selection['RecipientName'] == region]
    totProj = allentries['DonorName'].count()
    isnull = sorted_selection.loc[sorted_selection['RecipientName'] == region].isnull().sum()
    onlymissingyear = isnull['year'].sum()
    onlymissingdonor = isnull['ChannelName'].sum()
    perc = onlymissingyear * 100 / totProj
    percDonors = onlymissingdonor * perc / (totProj - onlymissingyear)
    
    print('total projects')
    print(totProj)
    print('total timestamped projects')
    print(totProj - onlymissingyear)
#     print('total projects with no donors')
#     print(totProj - onlymissingdonor)
    print('missing years abs:')
    print(onlymissingyear)
    print('missing years %:')
    print(perc)
    print('missing donors abs:')
    print(onlymissingdonor)
    print('% of timestamped projects with missing donors:')
    print(percDonors)
    
    print('-------')
# Out:
# Tanzania
# total projects
# 195
# total timestamped projects
# 107
# missing years abs:
# 88
# missing years %:
# 45.12820512820513
# missing donors abs:
# 52
# % of timestamped projects with missing donors:
# 21.93146417445483
# -------
# Bolivia
# total projects
# 136
# total timestamped projects
# 77
# missing years abs:
# 59
# missing years %:
# 43.38235294117647
# missing donors abs:
# 35
# % of timestamped projects with missing donors:
# 19.7192513368984
# -------
# Kenya
# total projects
# 159
# total timestamped projects
# 95
# missing years abs:
# 64
# missing years %:
# 40.25157232704402
# missing donors abs:
# 41
# % of timestamped projects with missing donors:
# 17.371731214829527
# -------
# Ethiopia
# total projects
# 60
# total timestamped projects
# 48
# missing years abs:
# 12
# missing years %:
# 20.0
# missing donors abs:
# 22
# % of timestamped projects with missing donors:
# 9.166666666666666
# -------
# Sudan
# total projects
# 29
# total timestamped projects
# 16
# missing years abs:
# 13
# missing years %:
# 44.827586206896555
# missing donors abs:
# 11
# % of timestamped projects with missing donors:
# 30.81896551724138
# -------
# Burundi
# total projects
# 48
# total timestamped projects
# 33
# missing years abs:
# 15
# missing years %:
# 31.25
# missing donors abs:
# 15
# % of timestamped projects with missing donors:
# 14.204545454545455
# -------
# Bangladesh
# total projects
# 24
# total timestamped projects
# 18
# missing years abs:
# 6
# missing years %:
# 25.0
# missing donors abs:
# 9
# % of timestamped projects with missing donors:
# 12.5
# -------
# Egypt
# total projects
# 114
# total timestamped projects
# 82
# missing years abs:
# 32
# missing years %:
# 28.07017543859649
# missing donors abs:
# 30
# % of timestamped projects with missing donors:
# 10.269576379974325
# -------
# Lebanon
# total projects
# 52
# total timestamped projects
# 36
# missing years abs:
# 16
# missing years %:
# 30.76923076923077
# missing donors abs:
# 10
# % of timestamped projects with missing donors:
# 8.547008547008547
# -------
# Rwanda
# total projects
# 38
# total timestamped projects
# 29
# missing years abs:
# 9
# missing years %:
# 23.68421052631579
# missing donors abs:
# 19
# % of timestamped projects with missing donors:
# 15.517241379310347
# -------
# India
# total projects
# 188
# total timestamped projects
# 145
# missing years abs:
# 43
# missing years %:
# 22.872340425531913
# missing donors abs:
# 41
# % of timestamped projects with missing donors:
# 6.4673514306676445
# -------
# Colombia
# total projects
# 23
# total timestamped projects
# 17
# missing years abs:
# 6
# missing years %:
# 26.08695652173913
# missing donors abs:
# 6
# % of timestamped projects with missing donors:
# 9.207161125319693
# -------
# Uganda
# total projects
# 142
# total timestamped projects
# 60
# missing years abs:
# 82
# missing years %:
# 57.74647887323944
# missing donors abs:
# 17
# % of timestamped projects with missing donors:
# 16.36150234741784
# -------
