# %%
from pandas import DataFrame, Grouper
import pandas as pd
import numpy as np
from datetime import datetime
import sys

from IPython.display import HTML

# %%
# import our own stuff
sys.path.append("../python/src")

from tools import read_water_data

# %%
# set some options
pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 600)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

datadir = "../data/"
cachedir = "../data/cache"

# %% [markdown]
# read all data provided by the oecd (check README.md for download locations of csv-files)

# %%
oecddf = read_water_data(setname="fullset",datadir=datadir,cachedir=cachedir)
# Out:
# Reading Datafrom cached file: ../data/cache/fullset.p

# %% [markdown]
# show a sample of the data

# %%
oecddf.sample()
# Out:
#         Year DonorCode    DonorName AgencyCode  \
# 161251  2017        11  Switzerland          4
#
#                                            AgencyName       CrsID  \
# 161251  Swiss Agency for Development and Co-operation  2017005663
#
#          ProjectNumber  InitialReport RecipientCode RecipientName RegionCode  \
# 161251  7F-09912.01.02            1.0           364     Nicaragua      10005
#
#                          RegionName IncomegroupCode IncomegroupName FlowCode  \
# 161251  Caribbean & Central America           10018           LMICs       11
#
#           FlowName Bi_Multi Category Finance_t Aid_t  USD_Commitment  \
# 161251  ODA Grants        1       10       110   C01        0.021326
#
#         USD_Disbursement  USD_Received  USD_Commitment_Defl  \
# 161251               NaN           NaN             0.021533
#
#         USD_Disbursement_Defl  USD_Received_Defl  USD_Adjustment  \
# 161251                    NaN                NaN             NaN
#
#         USD_Adjustment_Defl  USD_AmountUntied  USD_AmountPartialTied  \
# 161251                  NaN          0.021326                    NaN
#
#         USD_AmountTied  USD_AmountUntied_Defl  USD_AmountPartialTied_Defl  \
# 161251             NaN               0.021533                         NaN
#
#         USD_Amounttied_Defl  USD_IRTC  USD_Expert_Commitment  \
# 161251                  NaN       NaN                    NaN
#
#         USD_Expert_Extended  USD_Export_Credit CurrencyCode  \
# 161251                  NaN                NaN           11
#
#         Commitment_National  Disbursement_National  GrantEquiv  \
# 161251                0.021                    NaN         NaN
#
#         USD_GrantEquiv                  ShortDescription  \
# 161251             NaN  NI 44 SOCIEDAD CULTURA Y MEMORIA
#
#                             ProjectTitle PurposeCode             PurposeName  \
# 161251  NI 44 Sociedad Cultura y Memoria       16061  Culture and recreation
#
#        SectorCode                                   SectorName ChannelCode  \
# 161251        160  I.6. Other Social Infrastructure & Services       11001
#
#                ChannelName ChannelReportedName ParentChannelCode Geography  \
# 161251  Central Government                 NaN             11000       NaN
#
#        ExpectedStartDate CompletionDate LongDescription SDGfocus Gender  \
# 161251        2017-11-01     2018-08-31             NaN      NaN      1
#
#        Environment PDGG Trade RMNCH  DRR  Nutrition  Disability  FTC  PBA  \
# 161251           0    2   NaN     0  NaN        NaN         NaN  NaN  NaN
#
#         InvestmentProject  AssocFinance  Biodiversity  ClimateMitigation  \
# 161251                NaN           NaN           0.0                0.0
#
#         ClimateAdaptation  Desertification CommitmentDate  TypeRepayment  \
# 161251                0.0              0.0     2017-11-01            NaN
#
#         NumberRepayment Interest1  Interest2 Repaydate1 Repaydate2  \
# 161251              NaN       NaN        NaN        NaT        NaT
#
#         USD_Interest  USD_Outstanding  USD_Arrears_Principal  \
# 161251           NaN              NaN                    NaN
#
#         USD_Arrears_Interest BudgetIdent  CapitalExpend  PSIflag  PSIAddType  \
# 161251                   NaN       16061            NaN      NaN         NaN
#
#        PSIAddAssess PSIAddDevObj
# 161251          NaN          NaN

# %% [markdown]
# filter the oecd-data by commitment date. For the first subset
# * a: only take data into account with a commitmentdate greater then 2015-12-31.
# * b: remove every entry that cannot fall into any specific incomegroup-class b/c the project is focused on a greater region.
# * b.1: check how many projects are missing a IncomegroupName
# * c: group the data by recipientname and incomegroup
# * d: count how many projects with a donorname are in each incomegroup-subgroup of a country
# * e: reset the both indicies and set the index to the RecipientName
# * f: display the aggregated data

# %%
# a:
df = oecddf[oecddf["CommitmentDate"] > datetime(year=2015,month=12,day=31)]
# b:
df =  df[df['IncomegroupName'] != "Part I unallocated by income"]
# b.1"
display("total Projects with IncomegroupName: %d" %(df['IncomegroupName'].count()))
display("total Projects: %d" %(df['DonorName'].count()))
# c: 
gdf = df[['RecipientName','IncomegroupName','DonorName']].groupby(
    ["RecipientName","IncomegroupName"])
# d:
one = gdf.agg({'DonorName': 'count'})
# e:
one = one.reset_index().set_index("RecipientName") 
# f:
one
# Out:
# 'total Projects with IncomegroupName: 484527'
# 'total Projects: 484527'
#                                       IncomegroupName  DonorName
# RecipientName
# Afghanistan                                      LDCs       6864
# Albania                                         UMICs       2798
# Algeria                                         UMICs       1851
# Angola                                           LDCs       1999
# Antigua and Barbuda                             UMICs        251
# Argentina                                       UMICs       2443
# Armenia                                         LMICs       3064
# Azerbaijan                                      UMICs       1999
# Bangladesh                                       LDCs       8030
# Belarus                                         UMICs       2329
# Belize                                          UMICs        667
# Benin                                            LDCs       4021
# Bhutan                                           LDCs       1226
# Bolivia                                         LMICs       4727
# Bosnia and Herzegovina                          UMICs       4872
# Botswana                                        UMICs       1098
# Brazil                                          UMICs       5580
# Burkina Faso                                     LDCs       6191
# Burundi                                          LDCs       2860
# Cabo Verde                                      LMICs       1104
# Cambodia                                         LDCs       5940
# Cameroon                                        LMICs       4437
# Central African Republic                         LDCs       2380
# Chad                                             LDCs       2626
# Chile                                          MADCTs       1109
# China (People's Republic of)                    UMICs       7003
# Colombia                                        UMICs       8855
# Comoros                                          LDCs        815
# Congo                                           LMICs       1252
# Cook Islands                                    UMICs        188
# Costa Rica                                      UMICs       1553
# Cuba                                            UMICs       2282
# Côte d'Ivoire                                   LMICs       3394
# Democratic People's Republic of Korea      Other LICs        644
# Democratic Republic of the Congo                 LDCs       7550
# Djibouti                                         LDCs       1222
# Dominica                                        UMICs        324
# Dominican Republic                              UMICs       3164
# Ecuador                                         UMICs       3544
# Egypt                                           LMICs       5161
# El Salvador                                     LMICs       3221
# Equatorial Guinea                               UMICs        374
# Eritrea                                          LDCs        782
# Eswatini                                        LMICs       1114
# Ethiopia                                         LDCs      10455
# Fiji                                            UMICs       1666
# Gabon                                           UMICs        930
# Gambia                                           LDCs       1253
# Georgia                                         LMICs       4421
# Ghana                                           LMICs       6062
# Grenada                                         UMICs        276
# Guatemala                                       LMICs       5035
# Guinea                                           LDCs       2973
# Guinea-Bissau                                    LDCs       1359
# Guyana                                          UMICs       1037
# Haiti                                            LDCs       6422
# Honduras                                        LMICs       3753
# India                                           LMICs      12534
# Indonesia                                       LMICs       8421
# Iran                                            UMICs       1627
# Iraq                                            UMICs       4247
# Jamaica                                         UMICs       1533
# Jordan                                          LMICs       4907
# Kazakhstan                                      UMICs       2398
# Kenya                                           LMICs      10820
# Kiribati                                         LDCs        618
# Kosovo                                          LMICs       3314
# Kyrgyzstan                                      LMICs       3195
# Lao People's Democratic Republic                 LDCs       3566
# Lebanon                                         UMICs       4679
# Lesotho                                          LDCs       1287
# Liberia                                          LDCs       3420
# Libya                                           UMICs       1327
# Madagascar                                       LDCs       4962
# Malawi                                           LDCs       5568
# Malaysia                                        UMICs       1868
# Maldives                                        UMICs        684
# Mali                                             LDCs       7175
# Marshall Islands                                UMICs        518
# Mauritania                                       LDCs       2124
# Mauritius                                       UMICs        674
# Mexico                                          UMICs       4667
# Micronesia                                      LMICs        665
# Moldova                                         LMICs       3736
# Mongolia                                        LMICs       3219
# Montenegro                                      UMICs       1194
# Montserrat                                      UMICs        117
# Morocco                                         LMICs       5402
# Mozambique                                       LDCs       7217
# Myanmar                                          LDCs       7718
# Namibia                                         UMICs       1666
# Nauru                                           UMICs        270
# Nepal                                            LDCs       6915
# Nicaragua                                       LMICs       3732
# Niger                                            LDCs       4211
# Nigeria                                         LMICs       7118
# Niue                                            UMICs        150
# North Macedonia                                 UMICs       2454
# Pakistan                                        LMICs       6250
# Palau                                           UMICs        389
# Panama                                          UMICs       1531
# Papua New Guinea                                LMICs       1943
# Paraguay                                        UMICs       2238
# Peru                                            UMICs       7421
# Philippines                                     LMICs       6035
# Rwanda                                           LDCs       4523
# Saint Helena                                    UMICs        149
# Saint Lucia                                     UMICs        314
# Saint Vincent and the Grenadines                UMICs        269
# Samoa                                           UMICs        865
# Sao Tome and Principe                            LDCs        793
# Senegal                                          LDCs       7008
# Serbia                                          UMICs       4069
# Seychelles                                     MADCTs        204
# Sierra Leone                                     LDCs       2938
# Solomon Islands                                  LDCs       1042
# Somalia                                          LDCs       3842
# South Africa                                    UMICs       5529
# South Sudan                                      LDCs       4410
# Sri Lanka                                       LMICs       4130
# Sudan                                            LDCs       4052
# Suriname                                        UMICs        429
# Syrian Arab Republic                            LMICs       4482
# Tajikistan                                      LMICs       2965
# Tanzania                                         LDCs       9176
# Thailand                                        UMICs       3149
# Timor-Leste                                      LDCs       1945
# Togo                                             LDCs       2481
# Tokelau                                         LMICs         74
# Tonga                                           UMICs        775
# Tunisia                                         LMICs       3857
# Turkey                                          UMICs       3720
# Turkmenistan                                    UMICs        795
# Tuvalu                                           LDCs        353
# Uganda                                           LDCs       7919
# Ukraine                                         LMICs       8042
# Uruguay                                        MADCTs        766
# Uzbekistan                                      LMICs       2435
# Vanuatu                                          LDCs        974
# Venezuela                                       UMICs       1341
# Viet Nam                                        LMICs       7564
# Wallis and Futuna                               UMICs       2964
# West Bank and Gaza Strip                        LMICs       5861
# Yemen                                            LDCs       3040
# Zambia                                           LDCs       4875
# Zimbabwe                                   Other LICs       4134

# %% [markdown]
# filter the oecd-data by commitment date. For the second subset
#
# * a: only take data into account with a commitmentdate between 2000-12-31 and 2003-01-01
# * everything else as above

# %%
# a:
df = oecddf[oecddf["CommitmentDate"] > datetime(year=2000,month=12,day=31)]
df = df[df["CommitmentDate"] < datetime(year=2003,month=1,day=1)]
# b:
df =  df[df['IncomegroupName'] != "Part I unallocated by income"]
# b.1"
display("total Projects with IncomegroupName: %d" %(df['IncomegroupName'].count()))
display("total Projects: %d" %(df['DonorName'].count()))
# c: 
gdf = df[['RecipientName','IncomegroupName','DonorName']].groupby(
    ["RecipientName","IncomegroupName"])
# d:
two = gdf.agg({'DonorName': 'count'})
# e:
two = two.reset_index().set_index("RecipientName") 
# f:
two
# Out:
# 'total Projects with IncomegroupName: 134610'
# 'total Projects: 134610'
#                                       IncomegroupName  DonorName
# RecipientName
# Afghanistan                                      LDCs       1455
# Albania                                         UMICs       1319
# Algeria                                         UMICs        699
# Angola                                           LDCs       1210
# Anguilla                                       MADCTs         36
# Antigua and Barbuda                             UMICs         30
# Argentina                                       UMICs        788
# Armenia                                         LMICs        731
# Azerbaijan                                      UMICs        693
# Bahrain                                        MADCTs         35
# Bangladesh                                       LDCs       1826
# Barbados                                       MADCTs         74
# Belarus                                         UMICs         31
# Belize                                          UMICs        241
# Benin                                            LDCs        980
# Bhutan                                           LDCs        247
# Bolivia                                         LMICs       2208
# Bosnia and Herzegovina                          UMICs       1755
# Botswana                                        UMICs        323
# Brazil                                          UMICs       2544
# Burkina Faso                                     LDCs       1705
# Burundi                                          LDCs        926
# Cabo Verde                                      LMICs        913
# Cambodia                                         LDCs       1612
# Cameroon                                        LMICs       1119
# Central African Republic                         LDCs        343
# Chad                                             LDCs        771
# Chile                                          MADCTs        676
# China (People's Republic of)                    UMICs       3606
# Colombia                                        UMICs       1487
# Comoros                                          LDCs        155
# Congo                                           LMICs        605
# Cook Islands                                    UMICs        128
# Costa Rica                                      UMICs        429
# Croatia                                        MADCTs        603
# Cuba                                            UMICs        831
# Côte d'Ivoire                                   LMICs        742
# Democratic People's Republic of Korea      Other LICs        257
# Democratic Republic of the Congo                 LDCs       1757
# Djibouti                                         LDCs        416
# Dominica                                        UMICs        185
# Dominican Republic                              UMICs        867
# Ecuador                                         UMICs       1455
# Egypt                                           LMICs       1190
# El Salvador                                     LMICs       1387
# Equatorial Guinea                               UMICs        208
# Eritrea                                          LDCs        633
# Eswatini                                        LMICs        208
# Ethiopia                                         LDCs       3262
# Fiji                                            UMICs        199
# Gabon                                           UMICs        265
# Gambia                                           LDCs        556
# Georgia                                         LMICs       1010
# Ghana                                           LMICs       1340
# Grenada                                         UMICs        382
# Guatemala                                       LMICs       1760
# Guinea                                           LDCs        908
# Guinea-Bissau                                    LDCs        621
# Guyana                                          UMICs        315
# Haiti                                            LDCs        581
# Honduras                                        LMICs       1328
# India                                           LMICs       4444
# Indonesia                                       LMICs       2584
# Iran                                            UMICs        259
# Iraq                                            UMICs        241
# Jamaica                                         UMICs        752
# Jordan                                          LMICs        835
# Kazakhstan                                      UMICs        496
# Kenya                                           LMICs       1767
# Kiribati                                         LDCs        128
# Kosovo                                          LMICs          7
# Kyrgyzstan                                      LMICs        570
# Lao People's Democratic Republic                 LDCs       1107
# Lebanon                                         UMICs        863
# Lesotho                                          LDCs        586
# Liberia                                          LDCs        245
# Libya                                           UMICs          5
# Madagascar                                       LDCs       1190
# Malawi                                           LDCs       1137
# Malaysia                                        UMICs        350
# Maldives                                        UMICs        134
# Mali                                             LDCs       1088
# Malta                                          MADCTs         41
# Marshall Islands                                UMICs         56
# Mauritania                                       LDCs        784
# Mauritius                                       UMICs        264
# Mayotte                                        MADCTs        117
# Mexico                                          UMICs       1078
# Micronesia                                      LMICs         90
# Moldova                                         LMICs        785
# Mongolia                                        LMICs        790
# Montenegro                                      UMICs        197
# Montserrat                                      UMICs        157
# Morocco                                         LMICs       1731
# Mozambique                                       LDCs       2909
# Myanmar                                          LDCs        368
# Namibia                                         UMICs        764
# Nauru                                           UMICs         20
# Nepal                                            LDCs       1195
# Nicaragua                                       LMICs       2155
# Niger                                            LDCs        875
# Nigeria                                         LMICs       1339
# Niue                                            UMICs         88
# North Macedonia                                 UMICs        991
# Oman                                           MADCTs         79
# Pakistan                                        LMICs       1737
# Palau                                           UMICs         30
# Panama                                          UMICs        496
# Papua New Guinea                                LMICs        715
# Paraguay                                        UMICs        462
# Peru                                            UMICs       2088
# Philippines                                     LMICs       2186
# Rwanda                                           LDCs       1447
# Saint Helena                                    UMICs         87
# Saint Kitts and Nevis                          MADCTs         88
# Saint Lucia                                     UMICs        356
# Saint Vincent and the Grenadines                UMICs        209
# Samoa                                           UMICs        255
# Sao Tome and Principe                            LDCs        376
# Saudi Arabia                                   MADCTs         50
# Senegal                                          LDCs       1439
# Serbia                                          UMICs       2493
# Seychelles                                     MADCTs         94
# Sierra Leone                                     LDCs        836
# Slovenia                                       MADCTs        165
# Solomon Islands                                  LDCs        197
# Somalia                                          LDCs        410
# South Africa                                    UMICs       2083
# Sri Lanka                                       LMICs       1619
# Sudan                                            LDCs        963
# Suriname                                        UMICs        233
# Syrian Arab Republic                            LMICs        334
# Tajikistan                                      LMICs        759
# Tanzania                                         LDCs       2844
# Thailand                                        UMICs        758
# Timor-Leste                                      LDCs        600
# Togo                                             LDCs        321
# Tokelau                                         LMICs         36
# Tonga                                           UMICs        281
# Trinidad and Tobago                            MADCTs        116
# Tunisia                                         LMICs       1437
# Turkey                                          UMICs       1233
# Turkmenistan                                    UMICs        195
# Turks and Caicos Islands                       MADCTs         42
# Tuvalu                                           LDCs         75
# Uganda                                           LDCs       2868
# Ukraine                                         LMICs        381
# Uruguay                                        MADCTs        650
# Uzbekistan                                      LMICs        676
# Vanuatu                                          LDCs        237
# Venezuela                                       UMICs        483
# Viet Nam                                        LMICs       3054
# Wallis and Futuna                               UMICs         64
# West Bank and Gaza Strip                        LMICs       1469
# Yemen                                            LDCs        842
# Zambia                                           LDCs       1959
# Zimbabwe                                   Other LICs       1155

# %% [markdown]
# * a) dropping the counts from the two disjunced subsets since there are no difference in classifaction in the selected timeranges of the subsets; every country has only one incomegroup-classification
# * b) rename 'IncomegroupName' of the two datasets to 'ig-name-2015-plus' and 'ig-name-2001-2002'
# * c) add the feature / column of the second set (2001-2002) to the first for compare
# * d) compare both columns and store the result in the new column 'match'
# * e) display the data side by side

# %%
# a:
one.drop(columns=['DonorName'],inplace=True)
two.drop(columns=['DonorName'],inplace=True)
# b: 
one.rename(columns = {'IncomegroupName': 'ig-name-2015-plus'},inplace=True)
two.rename(columns = {'IncomegroupName': 'ig-name-2001-2002'},inplace=True)
# c:
one['ig-name-2001-2002'] = two['ig-name-2001-2002']
# d:
# Cook Islands                            True
# Costa Rica                              True
# Cuba                                    True
# Côte d'Ivoire                           True
# Democratic People's Republic of Korea   True
# Democratic Republic of the Congo        True
# Djibouti                                True
# Dominica                                True
# Dominican Republic                      True
# Ecuador                                 True
# Egypt                                   True
# El Salvador                             True
# Equatorial Guinea                       True
# Eritrea                                 True
# Eswatini                                True
# Ethiopia                                True
# Fiji                                    True
# Gabon                                   True
# Gambia                                  True
# Georgia                                 True
# Ghana                                   True
# Grenada                                 True
# Guatemala                               True
# Guinea                                  True
# Guinea-Bissau                           True
# Guyana                                  True
# Haiti                                   True
# Honduras                                True
# India                                   True
# Indonesia                               True
# Iran                                    True
# Iraq                                    True
# Jamaica                                 True
# Jordan                                  True
# Kazakhstan                              True
# Kenya                                   True
# Kiribati                                True
# Kosovo                                  True
# Kyrgyzstan                              True
# Lao People's Democratic Republic        True
# Lebanon                                 True
# Lesotho                                 True
# Liberia                                 True
# Libya                                   True
# Madagascar                              True
# Malawi                                  True
# Malaysia                                True
# Maldives                                True
# Mali                                    True
# Marshall Islands                        True
# Mauritania                              True
# Mauritius                               True
# Mexico                                  True
# Micronesia                              True
# Moldova                                 True
# Mongolia                                True
# Montenegro                              True
# Montserrat                              True
# Morocco                                 True
# Mozambique                              True
# Myanmar                                 True
# Namibia                                 True
# Nauru                                   True
# Nepal                                   True
# Nicaragua                               True
# Niger                                   True
# Nigeria                                 True
# Niue                                    True
# North Macedonia                         True
# Pakistan                                True
# Palau                                   True
# Panama                                  True
# Papua New Guinea                        True
# Paraguay                                True
# Peru                                    True
# Philippines                             True
# Rwanda                                  True
# Saint Helena                            True
# Saint Lucia                             True
# Saint Vincent and the Grenadines        True
# Samoa                                   True
# Sao Tome and Principe                   True
# Senegal                                 True
# Serbia                                  True
# Seychelles                              True
# Sierra Leone                            True
# Solomon Islands                         True
# Somalia                                 True
# South Africa                            True
# South Sudan                            False
# Sri Lanka                               True
# Sudan                                   True
# Suriname                                True
# Syrian Arab Republic                    True
# Tajikistan                              True
# Tanzania                                True
# Thailand                                True
# Timor-Leste                             True
# Togo                                    True
# Tokelau                                 True
# Tonga                                   True
# Tunisia                                 True
# Turkey                                  True
# Turkmenistan                            True
# Tuvalu                                  True
# Uganda                                  True
# Ukraine                                 True
# Uruguay                                 True
# Uzbekistan                              True
# Vanuatu                                 True
# Venezuela                               True
# Viet Nam                                True
# Wallis and Futuna                       True
# West Bank and Gaza Strip                True
# Yemen                                   True
# Zambia                                  True
# Zimbabwe                                True

# %% [markdown]
# It can be seen, that the both selected timeframes have identical incomegroup classifications(*). This implies, that within 15 years none of the country changed its classification. This does not match with the historical classification provided by the worldbank at https://datatopics.worldbank.org/world-development-indicators/the-world-by-income-and-region.html .  B/C those changes are backpropagated in the dataset of the oecd and replace earlier classification, this can lead to a false assumption, that in the past mostly UMICs got grands since they evolved from LDC or LMIC to UMIC.
#
# (*) south sudan did change b/c in 2002 it was not listed as a country, that received grants

# %% [markdown]
# Some noteable countries affected by this effect are:
# * thailand: changed 2009 form LMIC to UMIC
# * cambodia: changed 2015 from LDC to LMIC
# * china and ecuador: changed 2010 from LMIC to UMIC
# * iraq: changed 2012 from LMIC to UMIC
