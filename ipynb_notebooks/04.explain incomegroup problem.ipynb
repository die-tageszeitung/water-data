# %%
from pandas import DataFrame, Grouper
import pandas as pd
import numpy as np
from datetime import datetime
import sys

from IPython.display import HTML

# %%
# import our own stuff
sys.path.append("../python/src")

from tools import read_water_data

# %%
# set some options
pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 600)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

datadir = "../data/"
cachedir = "../data/cache"

# %% [markdown]
# read all data provided by the oecd (check README.md for download locations of csv-files)

# %%
oecddf = read_water_data(setname="fullset",datadir=datadir,cachedir=cachedir)
# Out:
# Reading Datafrom cached file: ../data/cache/fullset.p

# %% [markdown]
# show a sample of the data

# %%
oecddf.sample()
# Out:
#         Year DonorCode      DonorName AgencyCode     AgencyName        CrsID  \
# 128318  1991       302  United States         99  Miscellaneous  1976000016z
#
#        ProjectNumber InitialReport RecipientCode RecipientName RegionCode  \
# 128318           NaN             3           288        Zambia      10003
#
#              RegionName IncomegroupCode IncomegroupName FlowCode   FlowName  \
# 128318  South of Sahara           10016            LDCs       13  ODA Loans
#
#        Bi_Multi Category Finance_t Aid_t  USD_Commitment  USD_Disbursement  \
# 128318        1       10       421   NaN             NaN               0.0
#
#         USD_Received  USD_Commitment_Defl  USD_Disbursement_Defl  \
# 128318           0.0                  NaN                    0.0
#
#         USD_Received_Defl  USD_Adjustment  USD_Adjustment_Defl  \
# 128318                0.0             NaN                  NaN
#
#         USD_AmountUntied  USD_AmountPartialTied  USD_AmountTied  \
# 128318               NaN                    NaN             NaN
#
#         USD_AmountUntied_Defl  USD_AmountPartialTied_Defl  \
# 128318                    NaN                         NaN
#
#         USD_Amounttied_Defl  USD_IRTC  USD_Expert_Commitment  \
# 128318                  NaN       NaN                    NaN
#
#         USD_Expert_Extended  USD_Export_Credit CurrencyCode  \
# 128318                  NaN                NaN          302
#
#         Commitment_National  Disbursement_National  GrantEquiv  \
# 128318                  NaN                    0.0         NaN
#
#         USD_GrantEquiv                   ShortDescription ProjectTitle  \
# 128318             NaN  FOOD AID/FOOD SECURITY PROGRAMMES          NaN
#
#        PurposeCode      PurposeName SectorCode  \
# 128318       52010  Food assistance        520
#
#                                SectorName ChannelCode ChannelName  \
# 128318  VI.2. Development Food Assistance         NaN         NaN
#
#        ChannelReportedName ParentChannelCode Geography ExpectedStartDate  \
# 128318                 NaN               NaN       NaN               NaT
#
#        CompletionDate LongDescription SDGfocus Gender Environment PDGG Trade  \
# 128318            NaT             NaN      NaN    NaN         NaN  NaN   NaN
#
#        RMNCH  DRR  Nutrition  Disability  FTC  PBA  InvestmentProject  \
# 128318   NaN  NaN        NaN         NaN  NaN  NaN                NaN
#
#         AssocFinance  Biodiversity  ClimateMitigation  ClimateAdaptation  \
# 128318           NaN           NaN                NaN                NaN
#
#         Desertification CommitmentDate  TypeRepayment  NumberRepayment  \
# 128318              NaN            NaT            NaN              NaN
#
#        Interest1  Interest2 Repaydate1 Repaydate2  USD_Interest  \
# 128318       NaN        NaN        NaT        NaT          0.04
#
#         USD_Outstanding  USD_Arrears_Principal  USD_Arrears_Interest  \
# 128318             1.29                    0.0                   0.0
#
#        BudgetIdent  CapitalExpend  PSIflag  PSIAddType PSIAddAssess  \
# 128318       52010            NaN      NaN         NaN          NaN
#
#        PSIAddDevObj
# 128318          NaN

# %% [markdown]
# filter the oecd-data by commitment date. For the first subset
# * a: only take data into account with a commitmentdate greater then 2015-12-31.
# * b: remove every entry that cannot fall into any specific incomegroup-class b/c the project is focused on a greater region.
# * b.1: check how many projects are missing a IncomegroupName
# * c: group the data by recipientname and incomegroup
# * d: count how many projects with a donorname are in each incomegroup-subgroup of a country
# * e: reset the both indicies and set the index to the RecipientName
# * f: display the aggregated data

# %%
# a:
df = oecddf[oecddf["CommitmentDate"] > datetime(year=2015,month=12,day=31)]
# b:
df =  df[df['IncomegroupName'] != "Part I unallocated by income"]
# b.1"
display("total Projects with IncomegroupName: %d" %(df['IncomegroupName'].count()))
display("total Projects: %d" %(df['DonorName'].count()))
# c: 
gdf = df[['RecipientName','IncomegroupName','DonorName']].groupby(
    ["RecipientName","IncomegroupName"])
# d:
one = gdf.agg({'DonorName': 'count'})
# e:
one = one.reset_index().set_index("RecipientName") 
# f:
one
# Out:
# 'total Projects with IncomegroupName: 696257'
# 'total Projects: 696257'
#                                       IncomegroupName  DonorName
# RecipientName
# Afghanistan                                      LDCs       9352
# Albania                                         UMICs       4232
# Algeria                                         UMICs       2596
# Angola                                           LDCs       2874
# Antigua and Barbuda                             UMICs        322
# Argentina                                       UMICs       3482
# Armenia                                         LMICs       4285
# Azerbaijan                                      UMICs       3024
# Bangladesh                                       LDCs      12388
# Belarus                                         UMICs       3011
# Belize                                          UMICs       1059
# Benin                                            LDCs       5855
# Bhutan                                           LDCs       1877
# Bolivia                                         LMICs       6417
# Bosnia and Herzegovina                          UMICs       6522
# Botswana                                        UMICs       1621
# Brazil                                          UMICs       8038
# Burkina Faso                                     LDCs       8961
# Burundi                                          LDCs       4356
# Cabo Verde                                      LMICs       1691
# Cambodia                                         LDCs       8877
# Cameroon                                        LMICs       6498
# Central African Republic                         LDCs       3638
# Chad                                             LDCs       4189
# Chile                                          MADCTs       1111
# China (People's Republic of)                    UMICs      10305
# Colombia                                        UMICs      12872
# Comoros                                          LDCs       1366
# Congo                                           LMICs       2005
# Cook Islands                                    UMICs        297
# Costa Rica                                      UMICs       2103
# Cuba                                            UMICs       3124
# Côte d'Ivoire                                   LMICs       5223
# Democratic People's Republic of Korea      Other LICs        934
# Democratic Republic of the Congo                 LDCs      10502
# Djibouti                                         LDCs       1958
# Dominica                                        UMICs        469
# Dominican Republic                              UMICs       4889
# Ecuador                                         UMICs       4995
# Egypt                                           LMICs       7274
# El Salvador                                     LMICs       4540
# Equatorial Guinea                               UMICs        628
# Eritrea                                          LDCs       1323
# Eswatini                                        LMICs       1677
# Ethiopia                                         LDCs      14593
# Fiji                                            UMICs       2538
# Gabon                                           UMICs       1437
# Gambia                                           LDCs       1918
# Georgia                                         LMICs       6124
# Ghana                                           LMICs       8683
# Grenada                                         UMICs        413
# Guatemala                                       LMICs       6981
# Guinea                                           LDCs       4575
# Guinea-Bissau                                    LDCs       2174
# Guyana                                          UMICs       1523
# Haiti                                            LDCs       8382
# Honduras                                        LMICs       5311
# India                                           LMICs      18602
# Indonesia                                       LMICs      11865
# Iran                                            UMICs       2227
# Iraq                                            UMICs       5944
# Jamaica                                         UMICs       2282
# Jordan                                          LMICs       6922
# Kazakhstan                                      UMICs       3297
# Kenya                                           LMICs      15174
# Kiribati                                         LDCs        853
# Kosovo                                          LMICs       4389
# Kyrgyzstan                                      LMICs       4598
# Lao People's Democratic Republic                 LDCs       5410
# Lebanon                                         UMICs       6671
# Lesotho                                          LDCs       2125
# Liberia                                          LDCs       4718
# Libya                                           UMICs       1905
# Madagascar                                       LDCs       7322
# Malawi                                           LDCs       8096
# Malaysia                                        UMICs       2534
# Maldives                                        UMICs       1096
# Mali                                             LDCs       9922
# Marshall Islands                                UMICs        725
# Mauritania                                       LDCs       3268
# Mauritius                                       UMICs       1026
# Mexico                                          UMICs       6296
# Micronesia                                      LMICs        940
# Moldova                                         LMICs       5022
# Mongolia                                        LMICs       4686
# Montenegro                                      UMICs       1752
# Montserrat                                      UMICs        162
# Morocco                                         LMICs       7826
# Mozambique                                       LDCs      10567
# Myanmar                                          LDCs      10902
# Namibia                                         UMICs       2396
# Nauru                                           UMICs        371
# Nepal                                            LDCs      10230
# Nicaragua                                       LMICs       5235
# Niger                                            LDCs       6506
# Nigeria                                         LMICs      10835
# Niue                                            UMICs        213
# North Macedonia                                 UMICs       3508
# Pakistan                                        LMICs       9551
# Palau                                           UMICs        530
# Panama                                          UMICs       2256
# Papua New Guinea                                LMICs       3017
# Paraguay                                        UMICs       3213
# Peru                                            UMICs      10739
# Philippines                                     LMICs       8820
# Rwanda                                           LDCs       6581
# Saint Helena                                    UMICs        212
# Saint Lucia                                     UMICs        495
# Saint Vincent and the Grenadines                UMICs        430
# Samoa                                           UMICs       1286
# Sao Tome and Principe                            LDCs       1144
# Senegal                                          LDCs      10126
# Serbia                                          UMICs       5580
# Seychelles                                     MADCTs        205
# Sierra Leone                                     LDCs       4344
# Solomon Islands                                  LDCs       1520
# Somalia                                          LDCs       5624
# South Africa                                    UMICs       7514
# South Sudan                                      LDCs       6364
# Sri Lanka                                       LMICs       6082
# Sudan                                            LDCs       6279
# Suriname                                        UMICs        606
# Syrian Arab Republic                            LMICs       6282
# Tajikistan                                      LMICs       4206
# Tanzania                                         LDCs      12568
# Thailand                                        UMICs       4268
# Timor-Leste                                      LDCs       2850
# Togo                                             LDCs       3612
# Tokelau                                         LMICs         98
# Tonga                                           UMICs       1109
# Tunisia                                         LMICs       5649
# Turkey                                          UMICs       5107
# Turkmenistan                                    UMICs       1062
# Tuvalu                                           LDCs        519
# Uganda                                           LDCs      11465
# Ukraine                                         LMICs      10595
# Uruguay                                        MADCTs        767
# Uzbekistan                                      LMICs       3607
# Vanuatu                                          LDCs       1370
# Venezuela                                       UMICs       2023
# Viet Nam                                        LMICs      10866
# Wallis and Futuna                               UMICs       4450
# West Bank and Gaza Strip                        LMICs       8004
# Yemen                                            LDCs       4713
# Zambia                                           LDCs       6970
# Zimbabwe                                   Other LICs       5749

# %% [markdown]
# filter the oecd-data by commitment date. For the second subset
#
# * a: only take data into account with a commitmentdate between 2000-12-31 and 2003-01-01
# * everything else as above

# %%
# a:
df = oecddf[oecddf["CommitmentDate"] > datetime(year=2000,month=12,day=31)]
df = df[df["CommitmentDate"] < datetime(year=2003,month=1,day=1)]
# b:
df =  df[df['IncomegroupName'] != "Part I unallocated by income"]
# b.1"
display("total Projects with IncomegroupName: %d" %(df['IncomegroupName'].count()))
display("total Projects: %d" %(df['DonorName'].count()))
# c: 
gdf = df[['RecipientName','IncomegroupName','DonorName']].groupby(
    ["RecipientName","IncomegroupName"])
# d:
two = gdf.agg({'DonorName': 'count'})
# e:
two = two.reset_index().set_index("RecipientName") 
# f:
two
# Out:
# 'total Projects with IncomegroupName: 134973'
# 'total Projects: 134973'
#                                       IncomegroupName  DonorName
# RecipientName
# Afghanistan                                      LDCs       1459
# Albania                                         UMICs       1320
# Algeria                                         UMICs        706
# Angola                                           LDCs       1210
# Anguilla                                       MADCTs         36
# Antigua and Barbuda                             UMICs         30
# Argentina                                       UMICs        788
# Armenia                                         LMICs        731
# Azerbaijan                                      UMICs        693
# Bahrain                                        MADCTs         35
# Bangladesh                                       LDCs       1835
# Barbados                                       MADCTs         74
# Belarus                                         UMICs         32
# Belize                                          UMICs        241
# Benin                                            LDCs        980
# Bhutan                                           LDCs        247
# Bolivia                                         LMICs       2214
# Bosnia and Herzegovina                          UMICs       1757
# Botswana                                        UMICs        324
# Brazil                                          UMICs       2544
# Burkina Faso                                     LDCs       1707
# Burundi                                          LDCs        926
# Cabo Verde                                      LMICs        913
# Cambodia                                         LDCs       1615
# Cameroon                                        LMICs       1122
# Central African Republic                         LDCs        343
# Chad                                             LDCs        772
# Chile                                          MADCTs        676
# China (People's Republic of)                    UMICs       3682
# Colombia                                        UMICs       1487
# Comoros                                          LDCs        155
# Congo                                           LMICs        605
# Cook Islands                                    UMICs        128
# Costa Rica                                      UMICs        431
# Croatia                                        MADCTs        603
# Cuba                                            UMICs        831
# Côte d'Ivoire                                   LMICs        743
# Democratic People's Republic of Korea      Other LICs        258
# Democratic Republic of the Congo                 LDCs       1757
# Djibouti                                         LDCs        417
# Dominica                                        UMICs        186
# Dominican Republic                              UMICs        869
# Ecuador                                         UMICs       1457
# Egypt                                           LMICs       1194
# El Salvador                                     LMICs       1392
# Equatorial Guinea                               UMICs        208
# Eritrea                                          LDCs        635
# Eswatini                                        LMICs        210
# Ethiopia                                         LDCs       3262
# Fiji                                            UMICs        199
# Gabon                                           UMICs        265
# Gambia                                           LDCs        558
# Georgia                                         LMICs       1010
# Ghana                                           LMICs       1344
# Grenada                                         UMICs        382
# Guatemala                                       LMICs       1760
# Guinea                                           LDCs        910
# Guinea-Bissau                                    LDCs        621
# Guyana                                          UMICs        316
# Haiti                                            LDCs        581
# Honduras                                        LMICs       1332
# India                                           LMICs       4452
# Indonesia                                       LMICs       2600
# Iran                                            UMICs        259
# Iraq                                            UMICs        241
# Jamaica                                         UMICs        753
# Jordan                                          LMICs        839
# Kazakhstan                                      UMICs        499
# Kenya                                           LMICs       1769
# Kiribati                                         LDCs        128
# Kosovo                                          LMICs          7
# Kyrgyzstan                                      LMICs        570
# Lao People's Democratic Republic                 LDCs       1109
# Lebanon                                         UMICs        873
# Lesotho                                          LDCs        586
# Liberia                                          LDCs        245
# Libya                                           UMICs          5
# Madagascar                                       LDCs       1190
# Malawi                                           LDCs       1138
# Malaysia                                        UMICs        353
# Maldives                                        UMICs        134
# Mali                                             LDCs       1091
# Malta                                          MADCTs         41
# Marshall Islands                                UMICs         56
# Mauritania                                       LDCs        785
# Mauritius                                       UMICs        264
# Mayotte                                        MADCTs        117
# Mexico                                          UMICs       1078
# Micronesia                                      LMICs         90
# Moldova                                         LMICs        785
# Mongolia                                        LMICs        793
# Montenegro                                      UMICs        198
# Montserrat                                      UMICs        157
# Morocco                                         LMICs       1746
# Mozambique                                       LDCs       2911
# Myanmar                                          LDCs        368
# Namibia                                         UMICs        765
# Nauru                                           UMICs         20
# Nepal                                            LDCs       1197
# Nicaragua                                       LMICs       2155
# Niger                                            LDCs        875
# Nigeria                                         LMICs       1339
# Niue                                            UMICs         88
# North Macedonia                                 UMICs        991
# Oman                                           MADCTs         79
# Pakistan                                        LMICs       1739
# Palau                                           UMICs         30
# Panama                                          UMICs        500
# Papua New Guinea                                LMICs        715
# Paraguay                                        UMICs        463
# Peru                                            UMICs       2088
# Philippines                                     LMICs       2219
# Rwanda                                           LDCs       1447
# Saint Helena                                    UMICs         87
# Saint Kitts and Nevis                          MADCTs         88
# Saint Lucia                                     UMICs        357
# Saint Vincent and the Grenadines                UMICs        210
# Samoa                                           UMICs        255
# Sao Tome and Principe                            LDCs        376
# Saudi Arabia                                   MADCTs         50
# Senegal                                          LDCs       1444
# Serbia                                          UMICs       2495
# Seychelles                                     MADCTs         94
# Sierra Leone                                     LDCs        837
# Slovenia                                       MADCTs        165
# Solomon Islands                                  LDCs        197
# Somalia                                          LDCs        410
# South Africa                                    UMICs       2083
# Sri Lanka                                       LMICs       1634
# Sudan                                            LDCs        964
# Suriname                                        UMICs        234
# Syrian Arab Republic                            LMICs        336
# Tajikistan                                      LMICs        759
# Tanzania                                         LDCs       2844
# Thailand                                        UMICs        759
# Timor-Leste                                      LDCs        600
# Togo                                             LDCs        321
# Tokelau                                         LMICs         36
# Tonga                                           UMICs        281
# Trinidad and Tobago                            MADCTs        116
# Tunisia                                         LMICs       1451
# Turkey                                          UMICs       1241
# Turkmenistan                                    UMICs        195
# Turks and Caicos Islands                       MADCTs         42
# Tuvalu                                           LDCs         75
# Uganda                                           LDCs       2868
# Ukraine                                         LMICs        381
# Uruguay                                        MADCTs        650
# Uzbekistan                                      LMICs        681
# Vanuatu                                          LDCs        237
# Venezuela                                       UMICs        485
# Viet Nam                                        LMICs       3083
# Wallis and Futuna                               UMICs         64
# West Bank and Gaza Strip                        LMICs       1471
# Yemen                                            LDCs        845
# Zambia                                           LDCs       1959
# Zimbabwe                                   Other LICs       1155

# %% [markdown]
# * a) dropping the counts from the two disjunced subsets since there are no difference in classifaction in the selected timeranges of the subsets; every country has only one incomegroup-classification
# * b) rename 'IncomegroupName' of the two datasets to 'ig-name-2015-plus' and 'ig-name-2001-2002'
# * c) add the feature / column of the second set (2001-2002) to the first for compare
# * d) compare both columns and store the result in the new column 'match'
# * e) display the data side by side

# %%
# a:
one.drop(columns=['DonorName'],inplace=True)
two.drop(columns=['DonorName'],inplace=True)
# b: 
one.rename(columns = {'IncomegroupName': 'ig-name-2015-plus'},inplace=True)
two.rename(columns = {'IncomegroupName': 'ig-name-2001-2002'},inplace=True)
# c:
one['ig-name-2001-2002'] = two['ig-name-2001-2002']
# d:
# Cook Islands                            True
# Costa Rica                              True
# Cuba                                    True
# Côte d'Ivoire                           True
# Democratic People's Republic of Korea   True
# Democratic Republic of the Congo        True
# Djibouti                                True
# Dominica                                True
# Dominican Republic                      True
# Ecuador                                 True
# Egypt                                   True
# El Salvador                             True
# Equatorial Guinea                       True
# Eritrea                                 True
# Eswatini                                True
# Ethiopia                                True
# Fiji                                    True
# Gabon                                   True
# Gambia                                  True
# Georgia                                 True
# Ghana                                   True
# Grenada                                 True
# Guatemala                               True
# Guinea                                  True
# Guinea-Bissau                           True
# Guyana                                  True
# Haiti                                   True
# Honduras                                True
# India                                   True
# Indonesia                               True
# Iran                                    True
# Iraq                                    True
# Jamaica                                 True
# Jordan                                  True
# Kazakhstan                              True
# Kenya                                   True
# Kiribati                                True
# Kosovo                                  True
# Kyrgyzstan                              True
# Lao People's Democratic Republic        True
# Lebanon                                 True
# Lesotho                                 True
# Liberia                                 True
# Libya                                   True
# Madagascar                              True
# Malawi                                  True
# Malaysia                                True
# Maldives                                True
# Mali                                    True
# Marshall Islands                        True
# Mauritania                              True
# Mauritius                               True
# Mexico                                  True
# Micronesia                              True
# Moldova                                 True
# Mongolia                                True
# Montenegro                              True
# Montserrat                              True
# Morocco                                 True
# Mozambique                              True
# Myanmar                                 True
# Namibia                                 True
# Nauru                                   True
# Nepal                                   True
# Nicaragua                               True
# Niger                                   True
# Nigeria                                 True
# Niue                                    True
# North Macedonia                         True
# Pakistan                                True
# Palau                                   True
# Panama                                  True
# Papua New Guinea                        True
# Paraguay                                True
# Peru                                    True
# Philippines                             True
# Rwanda                                  True
# Saint Helena                            True
# Saint Lucia                             True
# Saint Vincent and the Grenadines        True
# Samoa                                   True
# Sao Tome and Principe                   True
# Senegal                                 True
# Serbia                                  True
# Seychelles                              True
# Sierra Leone                            True
# Solomon Islands                         True
# Somalia                                 True
# South Africa                            True
# South Sudan                            False
# Sri Lanka                               True
# Sudan                                   True
# Suriname                                True
# Syrian Arab Republic                    True
# Tajikistan                              True
# Tanzania                                True
# Thailand                                True
# Timor-Leste                             True
# Togo                                    True
# Tokelau                                 True
# Tonga                                   True
# Tunisia                                 True
# Turkey                                  True
# Turkmenistan                            True
# Tuvalu                                  True
# Uganda                                  True
# Ukraine                                 True
# Uruguay                                 True
# Uzbekistan                              True
# Vanuatu                                 True
# Venezuela                               True
# Viet Nam                                True
# Wallis and Futuna                       True
# West Bank and Gaza Strip                True
# Yemen                                   True
# Zambia                                  True
# Zimbabwe                                True

# %% [markdown]
# It can be seen, that the both selected timeframes have identical incomegroup classifications(*). This implies, that within 15 years none of the country changed its classification. This does not match with the historical classification provided by the worldbank at https://datatopics.worldbank.org/world-development-indicators/the-world-by-income-and-region.html .  B/C those changes are backpropagated in the dataset of the oecd and replace earlier classification, this can lead to a false assumption, that in the past mostly UMICs got grands since they evolved from LDC or LMIC to UMIC.
#
# (*) south sudan did change b/c in 2002 it was not listed as a country, that received grants

# %% [markdown]
# Some noteable countries affected by this effect are:
# * thailand: changed 2009 form LMIC to UMIC
# * cambodia: changed 2015 from LDC to LMIC
# * china and ecuador: changed 2010 from LMIC to UMIC
# * iraq: changed 2012 from LMIC to UMIC
